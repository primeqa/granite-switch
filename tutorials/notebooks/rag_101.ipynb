# %% [markdown]
# # RAG 101 - Corpus + Answerability
#
# > *Corpus:* IBM mt-rag-benchmark government-services passages (subset of the docs).
#
# **Duration:** ~15 min (first run, includes corpus embedding)
#
# The smallest end-to-end RAG demo this repo offers: build a vector corpus, retrieve passages for a query, and ask the model **"can these passages actually answer it?"**. No generation, no citations, no clarification - just the gate that decides whether RAG should even attempt an answer.
#
# *Why vLLM:* much faster inference in production environments; HF support for Granite Switch in mellea coming.
#
# **What you'll learn:**
# - How to stand up a ChromaDB corpus from a real-world dataset (subset of the docs from IBM mt-rag-benchmark government-services passages) and query it.
# - How `rag.check_answerability` decides whether retrieved documents can support an answer - the foundation that the larger RAG pipelines build on.
# - How to recognize the **unanswerable** exit, so your application can refuse instead of hallucinating.
#
# **Adapters used:** the `answerability` intrinsic from the [RAG](https://huggingface.co/ibm-granite/granitelib-rag-r1.0) library.
#
# ---
# **Prerequisites:** GPU runtime (T4 or better). Go to *Runtime → Change runtime type → T4 GPU*.
#
# New to mellea intrinsics? Start with [`hello_mellea.ipynb`](./hello_mellea.ipynb) for a softer walkthrough of each intrinsic in isolation. Full setup details (GPU sizes, HF auth, multi-GPU) are in [`PREREQUISITES.md`](../PREREQUISITES.md).

# %% [markdown]
# ## 0 · Install and set up

# %%
# Install granite-switch with tutorial dependencies (includes vLLM backend).
# %uv pip install -q "granite-switch[tutorials]"

# %%
import os
from pathlib import Path

from huggingface_hub import notebook_login

from granite_switch.tutorials.govt_data_loader import load_or_build_govt_chroma
from granite_switch.tutorials.vllm_server import (
    kill_stale_vllm_processes,
    launch_vllm,
    print_gpu_state,
    tail_log,
    wait_for_server,
)
from mellea.backends.openai import OpenAIBackend
from mellea.stdlib.components import Document as MelleaDocument
from mellea.stdlib.components.intrinsic import rag
from mellea.stdlib.context import ChatContext

try:
    from dotenv import load_dotenv
    load_dotenv(Path("../.env"), override=False)
except ImportError:
    pass

# %%
notebook_login()  # needed to pull ibm-granite models from the Hub

kill_stale_vllm_processes()
print_gpu_state()
# Out:
# No stale vLLM processes found.
# GPU state: NVIDIA GeForce RTX 5090, 5009 MiB, 27179 MiB

# %% [markdown]
# ## 1 · Launch vLLM server
#
# Start the Granite Switch model on port 8000. The server runs in the background; `wait_for_server` polls `/health` until it's ready.

# %%
VLLM_MODEL = "ibm-granite/granite-switch-4.1-3b-preview"
VLLM_PORT = 8000
MAX_MODEL_LEN = 10240  # 10k, fits comfortably on an T4 GPU.

vllm_proc = launch_vllm(
    model=VLLM_MODEL,
    port=VLLM_PORT,
    max_model_len=MAX_MODEL_LEN,
    log_file="/tmp/content/vllm_server.log",
)
if not wait_for_server(VLLM_PORT):
    tail_log("/tmp/content/vllm_server.log")
# Out:
# Launching ibm-granite/granite-switch-4.1-3b-preview on :8000 (pid 36992, log -> /tmp/content/vllm_server.log)
#   waiting for :8000 ... 291s
#   timed out after 300s - check the log file
# (APIServer pid=36992) INFO 05-22 11:38:03 [utils.py:299]  ▄▄ ▄█ █     █     █ ▀▄▀ █  version 0.19.1
# (APIServer pid=36992) INFO 05-22 11:38:03 [utils.py:299]   █▄█▀ █     █     █     █  model   ibm-granite/granite-switch-4.1-3b-preview
# (APIServer pid=36992) INFO 05-22 11:38:03 [utils.py:299]    ▀▀  ▀▀▀▀▀ ▀▀▀▀▀ ▀     ▀
# (APIServer pid=36992) INFO 05-22 11:38:03 [utils.py:299]
# (APIServer pid=36992) INFO 05-22 11:38:03 [utils.py:233] non-default args: {'model': 'ibm-granite/granite-switch-4.1-3b-preview', 'max_model_len': 10240}
# (APIServer pid=36992) INFO 05-22 11:38:11 [model.py:549] Resolved architecture: GraniteSwitchForCausalLM
# (APIServer pid=36992) INFO 05-22 11:38:11 [model.py:1678] Using max model len 10240
# (APIServer pid=36992) INFO 05-22 11:38:11 [vllm.py:790] Asynchronous scheduling is enabled.
# (EngineCore pid=37203) ✓ GraniteSwitchForCausalLM registered with vLLM
# (EngineCore pid=37203) INFO 05-22 11:38:17 [core.py:105] Initializing a V1 LLM engine (v0.19.1) with config: model='ibm-granite/granite-switch-4.1-3b-preview', speculative_config=None, tokenizer='ibm-granite/granite-switch-4.1-3b-preview', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=10240, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=ibm-granite/granite-switch-4.1-3b-preview, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'splitting_ops': ['vllm::unified_attention', 'vllm::unified_attention_with_output', 'vllm::unified_mla_attention', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::gdn_attention_core', 'vllm::olmo_hybrid_gdn_full_forward', 'vllm::kda_attention', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_images_per_batch': 0, 'compile_sizes': [], 'compile_ranges_endpoints': [2048], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'size_asserts': False, 'alignment_asserts': False, 'scalar_asserts': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# (EngineCore pid=37203) WARNING 05-22 11:38:17 [interface.py:525] Using 'pin_memory=False' as WSL is detected. This may slow down the performance.
# (EngineCore pid=37203) INFO 05-22 11:38:17 [parallel_state.py:1400] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.31.47.206:41197 backend=nccl
# (EngineCore pid=37203) INFO 05-22 11:38:17 [parallel_state.py:1716] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=37203) INFO 05-22 11:38:18 [gpu_model_runner.py:4735] Starting to load model ibm-granite/granite-switch-4.1-3b-preview...
# (EngineCore pid=37203) INFO 05-22 11:38:19 [cuda.py:334] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=37203) INFO 05-22 11:38:19 [flash_attn.py:596] Using FlashAttention version 2
# (EngineCore pid=37203) <frozen importlib._bootstrap_external>:1325: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# (EngineCore pid=37203) <frozen importlib._bootstrap_external>:1325: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# (EngineCore pid=37203) INFO 05-22 11:41:33 [weight_utils.py:581] Time spent downloading weights for ibm-granite/granite-switch-4.1-3b-preview: 176.587830 seconds
# (EngineCore pid=37203)
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## 2 · Configuration
# Endpoints, model IDs, and corpus paths. Every value falls back to a sensible default, so the cell runs as-is if your vLLM server is on `localhost:8000`.

# %%
# ── vLLM server ───────────────────────────────────────────────────────────────
# URL of the running vLLM OpenAI-compatible endpoint.
VLLM_BASE_URL = os.environ.get("VLLM_BASE_URL", "http://localhost:8000/v1")

# Model name as reported by GET /v1/models (usually the path/repo used at launch).
VLLM_MODEL_NAME = os.environ.get("VLLM_MODEL_NAME", "ibm-granite/granite-switch-4.1-3b-preview")

# HF Hub repo ID (or local path) to load I/O configs for the embedded adapters.
GRANITE_SWITCH_SOURCE = os.environ.get("GRANITE_SWITCH_SOURCE", VLLM_MODEL_NAME)

# ── Embedding model + ChromaDB persistence ───────────────────────────────────
EMBEDDING_MODEL_ID = "ibm-granite/granite-embedding-small-english-r2"
CHROMA_PATH = "./govt_chroma"

# ── Corpus source (only fetched when building from scratch) ──────────────────
GOVT_JSONL_URL  = "https://github.com/IBM/mt-rag-benchmark/raw/main/corpora/passage_level/govt.jsonl.zip"
GOVT_JSONL_PATH = "./govt.jsonl"

# TOP_K = passages retrieved per query. Small here because we only feed them to
# answerability — no generation budget to worry about.
TOP_K = 5

print(f"vLLM:      {VLLM_BASE_URL}  ({VLLM_MODEL_NAME})")
print(f"Embedding: {EMBEDDING_MODEL_ID}")
print(f"ChromaDB:  {CHROMA_PATH}")
# Out:
# vLLM:      http://localhost:8000/v1  (ibm-granite/granite-switch-4.1-3b-preview)
# Embedding: ibm-granite/granite-embedding-small-english-r2
# ChromaDB:  ./govt_chroma

# %% [markdown]
# ## 3 · Build or load the vector corpus
#
# `load_or_build_govt_chroma` is the corpus half of RAG, packaged so this notebook stays focused on retrieval and answerability:
#
# 1. Downloads `govt.jsonl.zip` (~50 MB, 49k government-service passages from [IBM mt-rag-benchmark](https://github.com/IBM/mt-rag-benchmark)) on first run.
# 2. Embeds each passage with `ibm-granite/granite-embedding-small-english-r2`.
# 3. Persists the index to `./govt_chroma` so subsequent runs load instantly.
#
# > **Note:** to keep the tutorial fast, we filter most non-related docs and embed only the curated subset that the demo queries actually retrieve. For a full corpus load, set `load_only_tutorial_docs=False` in the call below.

# %%
chroma_collection = load_or_build_govt_chroma(
    chroma_path             = CHROMA_PATH,
    jsonl_path              = GOVT_JSONL_PATH,
    jsonl_url               = GOVT_JSONL_URL,
    embedding_model_id      = EMBEDDING_MODEL_ID,
    load_only_tutorial_docs = True,
    device                  = "cpu",
)
print(f"Corpus ready — {chroma_collection.count():,} passages indexed.")
# Out:
# Loading weights:   0%|          | 0/74 [00:00<?, ?it/s]
# Granite embedding model ready on cpu  (ibm-granite/granite-embedding-small-english-r2)
# Loaded from ./govt_chroma  (137 docs).
# Corpus ready — 137 passages indexed.
# /home/raduf/sandbox2/granite-switch/src/granite_switch/tutorials/govt_data_loader.py:147: UserWarning: Embedding of the passages on CPU will take hours. Expected runtime is ~2 min on a single consumer GPU for this dataset. Consider running on a GPU host, or sharing a pre-built ./govt_chroma directory.
#   granite_ef = embedding_fn or GraniteEmbeddingFunction(**ef_kwargs)

# %% [markdown]
# ## 4 · Connect to vLLM via mellea
# Registers the Granite Switch embedded adapters so `rag.check_answerability` routes to the correct control token.

# %%
backend = OpenAIBackend(
    model_id=VLLM_MODEL_NAME,
    base_url=VLLM_BASE_URL,
    api_key="unused",
)
backend.register_embedded_adapter_model(GRANITE_SWITCH_SOURCE)
print(f"Backend ready — adapters: {backend.list_adapters()}")
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# Backend ready — adapters: ['citations_lora', 'query_rewrite_alora', 'query_clarification_alora', 'hallucination_detection_lora', 'answerability_alora', 'factuality-detection_alora', 'policy-guardrails_alora', 'factuality-correction_alora', 'guardian-core_alora', 'uncertainty_alora', 'requirement-check_alora', 'context-attribution_lora']

# %% [markdown]
# ## 5 · Ask: can the corpus answer this?
#
# Two steps per query:
#
# 1. **Retrieve** the top-K most similar passages from ChromaDB.
# 2. **Check answerability** — `rag.check_answerability` returns the string `"answerable"` or `"unanswerable"`.
#
# That's the entire RAG gate. In a full pipeline you'd only call the generation model when the verdict is `answerable`; on `unanswerable` you refuse and tell the user the corpus doesn't cover their question.

# %%
def answerable(query: str, top_k: int = TOP_K) -> str:
    """Retrieve top-K passages and ask the model whether they can answer the query."""
    results = chroma_collection.query(query_texts=[query], n_results=top_k)
    docs = [MelleaDocument(doc_id=str(i), text=t) for i, t in enumerate(results["documents"][0])]

    verdict = rag.check_answerability(query, docs, ChatContext(), backend)

    glyph = "✅" if verdict == "answerable" else "🔍"
    preview = " ".join(docs[0].text.split())
    print(f"{glyph} {verdict.upper():13s}  query: {query}")
    print(f"retrieved {len(docs)} passages; top match: {preview}")
    return verdict

# %%
query="How do I check the status of my federal tax refund?"
results = chroma_collection.query(query_texts=[query], n_results=5)
docs = [MelleaDocument(doc_id=str(i), text=t) for i, t in enumerate(results["documents"][0])]
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
 verdict = rag.check_answerability(query, docs, ChatContext(), backend)
# Out:
# === 11:51:24-INFO ======
# Tools for call: dict_keys([])
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection.py:101, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return await self._connection.handle_async_request(request)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection.py:78, in AsyncHTTPConnection.handle_async_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = await self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection.py:124, in AsyncHTTPConnection._connect(self, request)
#     123 async with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = await self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_backends/auto.py:31, in AutoBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      30 await self._init_backend()
# ---> 31 return await self._backend.connect_tcp(
#      32     host,
#      33     port,
#      34     timeout=timeout,
#      35     local_address=local_address,
#      36     socket_options=socket_options,
#      37 )
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_backends/anyio.py:113, in AnyIOBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     108 exc_map = {
#     109     TimeoutError: ConnectTimeout,
#     110     OSError: ConnectError,
#     111     anyio.BrokenResourceError: ConnectError,
#     112 }
# --> 113 with map_exceptions(exc_map):
#     114     with anyio.fail_after(timeout):
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: All connection attempts failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_base_client.py:1648, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1647 try:
# -> 1648     response = await self._send_request(
#    1649         request,
#    1650         stream=stream or self._should_stream_response_body(request=request),
#    1651         **kwargs,
#    1652     )
#    1653 except httpx.TimeoutException as err:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_client.py:946, in AsyncOpenAI._send_request(self, request, stream, **kwargs)
#     938 @override
#     939 async def _send_request(
#     940     self,
#    (...)    944     **kwargs: Unpack[HttpxSendArgs],
#     945 ) -> httpx.Response:
# --> 946     return await self._send_with_auth_retry(request, stream=stream, **kwargs)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_client.py:924, in AsyncOpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     922         used_workload_identity_auth = True
# --> 924 response = await super()._send_request(request, stream=stream, **kwargs)
#     925 if (
#     926     response.status_code == 401
#     927     and self._workload_identity_auth is not None
#     928     and used_workload_identity_auth
#     929     and not retried
#     930 ):
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_base_client.py:1571, in AsyncAPIClient._send_request(self, request, stream, **kwargs)
#    1564 async def _send_request(
#    1565     self,
#    1566     request: httpx.Request,
#    (...)   1569     **kwargs: Unpack[HttpxSendArgs],
#    1570 ) -> httpx.Response:
# -> 1571     return await self._client.send(request, stream=stream, **kwargs)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_transports/default.py:393, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
# --> 393 with map_httpcore_exceptions():
#     394     resp = await self._pool.handle_async_request(req)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: All connection attempts failed
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 verdict = rag.check_answerability(query, docs, ChatContext(), backend)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/stdlib/components/intrinsic/rag.py:39, in check_answerability(question, documents, context, backend)
#      19 """Test a user's question for answerability.
#      20
#      21 Intrinsic function that checks whether the question in the last user turn of a
#    (...)     36     A string value of either "answerable" or "unanswerable"
#      37 """
#      38 question, context = _resolve_question(question, context, backend)
# ---> 39 result_json = call_intrinsic(
#      40     "answerability",
#      41     context.add(
#      42         Message("user", question, documents=_coerce_to_documents(documents))
#      43     ),
#      44     backend,
#      45 )
#      46 return result_json["answerability"]
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/stdlib/components/intrinsic/_util.py:158, in call_intrinsic(intrinsic_name, context, backend, kwargs, model_options)
#     155 if model_options is not None:
#     156     default_opts.update(model_options)
# --> 158 model_output_thunk, _ = mfuncs.act(
#     159     intrinsic,
#     160     context,
#     161     backend,
#     162     model_options=default_opts,
#     163     tool_calls=True,
#     164     # No rejection sampling, please
#     165     strategy=None,
#     166 )
#     168 # act() can return a future. Don't know how to handle one from non-async code.
#     169 assert model_output_thunk.is_computed()
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/stdlib/functional.py:107, in act(action, context, backend, requirements, strategy, return_sampling_results, format, model_options, tool_calls)
#      78 def act(
#      79     action: Component[S],
#      80     context: Context,
#    (...)     88     tool_calls: bool = False,
#      89 ) -> tuple[ComputedModelOutputThunk[S], Context] | SamplingResult[S]:
#      90     """Runs a generic action, and adds both the action and the result to the context.
#      91
#      92     Args:
#    (...)    105         Always returns ComputedModelOutputThunk since sync functions must await completion.
#     106     """
# --> 107     out = _run_async_in_thread(
#     108         aact(
#     109             action,
#     110             context,
#     111             backend,
#     112             requirements=requirements,
#     113             strategy=strategy,
#     114             return_sampling_results=return_sampling_results,
#     115             format=format,
#     116             model_options=model_options,
#     117             tool_calls=tool_calls,
#     118             silence_context_type_warning=True,  # We can safely silence this here since it's in a sync function.
#     119             await_result=True,  # Sync functions must always await
#     120         )  # type: ignore[call-overload]
#     121     )
#     123     computed = False
#     124     if isinstance(out, SamplingResult):
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/helpers/event_loop_helper.py:105, in _run_async_in_thread(co)
#      84 def _run_async_in_thread(co: Coroutine[Any, Any, R]) -> R:
#      85     """Call to run async code from synchronous code in Mellea.
#      86
#      87     In Mellea, we utilize async code underneath sync code to speed up
#    (...)    103         output of the coroutine
#     104     """
# --> 105     return __event_loop_handler(co)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/helpers/event_loop_helper.py:77, in _EventLoopHandler.__call__(self, co)
#      74 if self._event_loop == get_current_event_loop():
#      75     # If this gets called from the same event loop, launch in a separate thread to prevent blocking.
#      76     return _EventLoopHandler()(co)
# ---> 77 return asyncio.run_coroutine_threadsafe(co, self._event_loop).result()
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/stdlib/functional.py:646, in aact(action, context, backend, requirements, strategy, return_sampling_results, format, model_options, tool_calls, silence_context_type_warning, await_result)
#     644 # Only await and wrap if await_result is True
#     645 if await_result:
# --> 646     await result.avalue()
#     648     # ._generate_log should never be None after generation.
#     649     assert result._generate_log is not None
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/core/base.py:425, in ModelOutputThunk.avalue(self)
#     420     raise RuntimeError(
#     421         f"Cannot use `ModelOutputThunk.avalue()` when the generate function is using `{self._generate_type.name}`"
#     422     )
#     424 while not self._computed:
# --> 425     await self.astream()
#     427 assert self.value is not None  # If computed, the value cannot be None.
#     428 return self.value
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/core/base.py:533, in ModelOutputThunk.astream(self)
#     528         err_payload = GenerationErrorPayload(
#     529             exception=chunks[-1], model_output=self
#     530         )
#     531         await invoke_hook(HookType.GENERATION_ERROR, err_payload)
# --> 533     raise chunks[-1]
#     535 for chunk in chunks:
#     536     assert self._process is not None
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/helpers/async_helpers.py:31, in send_to_queue(co, aqueue)
#      29 try:
#      30     if isinstance(co, Coroutine):
# ---> 31         aresponse = await co
#      32     else:
#      33         # Some backends (hf) don't actually return their iterator from an
#      34         # async function. As a result, there's no coroutine to wait for here.
#      35         aresponse = co
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:2739, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2692 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2693 async def create(
#    2694     self,
#    (...)   2736     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2737 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2738     validate_response_format(response_format)
# -> 2739     return await self._post(
#    2740         "/chat/completions",
#    2741         body=await async_maybe_transform(
#    2742             {
#    2743                 "messages": messages,
#    2744                 "model": model,
#    2745                 "audio": audio,
#    2746                 "frequency_penalty": frequency_penalty,
#    2747                 "function_call": function_call,
#    2748                 "functions": functions,
#    2749                 "logit_bias": logit_bias,
#    2750                 "logprobs": logprobs,
#    2751                 "max_completion_tokens": max_completion_tokens,
#    2752                 "max_tokens": max_tokens,
#    2753                 "metadata": metadata,
#    2754                 "modalities": modalities,
#    2755                 "n": n,
#    2756                 "parallel_tool_calls": parallel_tool_calls,
#    2757                 "prediction": prediction,
#    2758                 "presence_penalty": presence_penalty,
#    2759                 "prompt_cache_key": prompt_cache_key,
#    2760                 "prompt_cache_retention": prompt_cache_retention,
#    2761                 "reasoning_effort": reasoning_effort,
#    2762                 "response_format": response_format,
#    2763                 "safety_identifier": safety_identifier,
#    2764                 "seed": seed,
#    2765                 "service_tier": service_tier,
#    2766                 "stop": stop,
#    2767                 "store": store,
#    2768                 "stream": stream,
#    2769                 "stream_options": stream_options,
#    2770                 "temperature": temperature,
#    2771                 "tool_choice": tool_choice,
#    2772                 "tools": tools,
#    2773                 "top_logprobs": top_logprobs,
#    2774                 "top_p": top_p,
#    2775                 "user": user,
#    2776                 "verbosity": verbosity,
#    2777                 "web_search_options": web_search_options,
#    2778             },
#    2779             completion_create_params.CompletionCreateParamsStreaming
#    2780             if stream
#    2781             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2782         ),
#    2783         options=make_request_options(
#    2784             extra_headers=extra_headers,
#    2785             extra_query=extra_query,
#    2786             extra_body=extra_body,
#    2787             timeout=timeout,
#    2788             security={"bearer_auth": True},
#    2789         ),
#    2790         cast_to=ChatCompletion,
#    2791         stream=stream or False,
#    2792         stream_cls=AsyncStream[ChatCompletionChunk],
#    2793     )
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_base_client.py:1931, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1922     warnings.warn(
#    1923         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1924         "Please pass raw bytes via the `content` parameter instead.",
#    1925         DeprecationWarning,
#    1926         stacklevel=2,
#    1927     )
#    1928 opts = FinalRequestOptions.construct(
#    1929     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1930 )
# -> 1931 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_base_client.py:1683, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1680         continue
#    1682     log.debug("Raising connection error")
# -> 1683     raise APIConnectionError(request=request) from err
#    1685 log.debug(
#    1686     'HTTP Response: %s %s "%i %s" %s',
#    1687     request.method,
#    (...)   1691     response.headers,
#    1692 )
#    1693 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
# Q1 — answerable: government-service questions are exactly what this corpus covers.
_ = answerable("How do I check the status of my federal tax refund?")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# === 11:46:52-INFO ======
# Tools for call: dict_keys([])
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection.py:101, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return await self._connection.handle_async_request(request)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection.py:78, in AsyncHTTPConnection.handle_async_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = await self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_async/connection.py:124, in AsyncHTTPConnection._connect(self, request)
#     123 async with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = await self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_backends/auto.py:31, in AutoBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      30 await self._init_backend()
# ---> 31 return await self._backend.connect_tcp(
#      32     host,
#      33     port,
#      34     timeout=timeout,
#      35     local_address=local_address,
#      36     socket_options=socket_options,
#      37 )
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_backends/anyio.py:113, in AnyIOBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     108 exc_map = {
#     109     TimeoutError: ConnectTimeout,
#     110     OSError: ConnectError,
#     111     anyio.BrokenResourceError: ConnectError,
#     112 }
# --> 113 with map_exceptions(exc_map):
#     114     with anyio.fail_after(timeout):
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: All connection attempts failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_base_client.py:1648, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1647 try:
# -> 1648     response = await self._send_request(
#    1649         request,
#    1650         stream=stream or self._should_stream_response_body(request=request),
#    1651         **kwargs,
#    1652     )
#    1653 except httpx.TimeoutException as err:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_client.py:946, in AsyncOpenAI._send_request(self, request, stream, **kwargs)
#     938 @override
#     939 async def _send_request(
#     940     self,
#    (...)    944     **kwargs: Unpack[HttpxSendArgs],
#     945 ) -> httpx.Response:
# --> 946     return await self._send_with_auth_retry(request, stream=stream, **kwargs)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_client.py:924, in AsyncOpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     922         used_workload_identity_auth = True
# --> 924 response = await super()._send_request(request, stream=stream, **kwargs)
#     925 if (
#     926     response.status_code == 401
#     927     and self._workload_identity_auth is not None
#     928     and used_workload_identity_auth
#     929     and not retried
#     930 ):
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_base_client.py:1571, in AsyncAPIClient._send_request(self, request, stream, **kwargs)
#    1564 async def _send_request(
#    1565     self,
#    1566     request: httpx.Request,
#    (...)   1569     **kwargs: Unpack[HttpxSendArgs],
#    1570 ) -> httpx.Response:
# -> 1571     return await self._client.send(request, stream=stream, **kwargs)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_transports/default.py:393, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
# --> 393 with map_httpcore_exceptions():
#     394     resp = await self._pool.handle_async_request(req)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: All connection attempts failed
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Q1 — answerable: government-service questions are exactly what this corpus covers.
# ----> 2 _ = answerable("How do I check the status of my federal tax refund?")
#
# Cell In[8], line 6, in answerable(query, top_k)
#       2     """Retrieve top-K passages and ask the model whether they can answer the query."""
#       3     results = chroma_collection.query(query_texts=[query], n_results=top_k)
#       4     docs = [MelleaDocument(doc_id=str(i), text=t) for i, t in enumerate(results["documents"][0])]
#       5
# ----> 6     verdict = rag.check_answerability(query, docs, ChatContext(), backend)
#       7
#       8     glyph = "✅" if verdict == "answerable" else "🔍"
#       9     preview = " ".join(docs[0].text.split())
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/stdlib/components/intrinsic/rag.py:39, in check_answerability(question, documents, context, backend)
#      19 """Test a user's question for answerability.
#      20
#      21 Intrinsic function that checks whether the question in the last user turn of a
#    (...)     36     A string value of either "answerable" or "unanswerable"
#      37 """
#      38 question, context = _resolve_question(question, context, backend)
# ---> 39 result_json = call_intrinsic(
#      40     "answerability",
#      41     context.add(
#      42         Message("user", question, documents=_coerce_to_documents(documents))
#      43     ),
#      44     backend,
#      45 )
#      46 return result_json["answerability"]
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/stdlib/components/intrinsic/_util.py:158, in call_intrinsic(intrinsic_name, context, backend, kwargs, model_options)
#     155 if model_options is not None:
#     156     default_opts.update(model_options)
# --> 158 model_output_thunk, _ = mfuncs.act(
#     159     intrinsic,
#     160     context,
#     161     backend,
#     162     model_options=default_opts,
#     163     tool_calls=True,
#     164     # No rejection sampling, please
#     165     strategy=None,
#     166 )
#     168 # act() can return a future. Don't know how to handle one from non-async code.
#     169 assert model_output_thunk.is_computed()
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/stdlib/functional.py:107, in act(action, context, backend, requirements, strategy, return_sampling_results, format, model_options, tool_calls)
#      78 def act(
#      79     action: Component[S],
#      80     context: Context,
#    (...)     88     tool_calls: bool = False,
#      89 ) -> tuple[ComputedModelOutputThunk[S], Context] | SamplingResult[S]:
#      90     """Runs a generic action, and adds both the action and the result to the context.
#      91
#      92     Args:
#    (...)    105         Always returns ComputedModelOutputThunk since sync functions must await completion.
#     106     """
# --> 107     out = _run_async_in_thread(
#     108         aact(
#     109             action,
#     110             context,
#     111             backend,
#     112             requirements=requirements,
#     113             strategy=strategy,
#     114             return_sampling_results=return_sampling_results,
#     115             format=format,
#     116             model_options=model_options,
#     117             tool_calls=tool_calls,
#     118             silence_context_type_warning=True,  # We can safely silence this here since it's in a sync function.
#     119             await_result=True,  # Sync functions must always await
#     120         )  # type: ignore[call-overload]
#     121     )
#     123     computed = False
#     124     if isinstance(out, SamplingResult):
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/helpers/event_loop_helper.py:105, in _run_async_in_thread(co)
#      84 def _run_async_in_thread(co: Coroutine[Any, Any, R]) -> R:
#      85     """Call to run async code from synchronous code in Mellea.
#      86
#      87     In Mellea, we utilize async code underneath sync code to speed up
#    (...)    103         output of the coroutine
#     104     """
# --> 105     return __event_loop_handler(co)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/helpers/event_loop_helper.py:77, in _EventLoopHandler.__call__(self, co)
#      74 if self._event_loop == get_current_event_loop():
#      75     # If this gets called from the same event loop, launch in a separate thread to prevent blocking.
#      76     return _EventLoopHandler()(co)
# ---> 77 return asyncio.run_coroutine_threadsafe(co, self._event_loop).result()
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/stdlib/functional.py:646, in aact(action, context, backend, requirements, strategy, return_sampling_results, format, model_options, tool_calls, silence_context_type_warning, await_result)
#     644 # Only await and wrap if await_result is True
#     645 if await_result:
# --> 646     await result.avalue()
#     648     # ._generate_log should never be None after generation.
#     649     assert result._generate_log is not None
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/core/base.py:425, in ModelOutputThunk.avalue(self)
#     420     raise RuntimeError(
#     421         f"Cannot use `ModelOutputThunk.avalue()` when the generate function is using `{self._generate_type.name}`"
#     422     )
#     424 while not self._computed:
# --> 425     await self.astream()
#     427 assert self.value is not None  # If computed, the value cannot be None.
#     428 return self.value
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/core/base.py:533, in ModelOutputThunk.astream(self)
#     528         err_payload = GenerationErrorPayload(
#     529             exception=chunks[-1], model_output=self
#     530         )
#     531         await invoke_hook(HookType.GENERATION_ERROR, err_payload)
# --> 533     raise chunks[-1]
#     535 for chunk in chunks:
#     536     assert self._process is not None
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/mellea/helpers/async_helpers.py:31, in send_to_queue(co, aqueue)
#      29 try:
#      30     if isinstance(co, Coroutine):
# ---> 31         aresponse = await co
#      32     else:
#      33         # Some backends (hf) don't actually return their iterator from an
#      34         # async function. As a result, there's no coroutine to wait for here.
#      35         aresponse = co
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:2739, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2692 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2693 async def create(
#    2694     self,
#    (...)   2736     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2737 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2738     validate_response_format(response_format)
# -> 2739     return await self._post(
#    2740         "/chat/completions",
#    2741         body=await async_maybe_transform(
#    2742             {
#    2743                 "messages": messages,
#    2744                 "model": model,
#    2745                 "audio": audio,
#    2746                 "frequency_penalty": frequency_penalty,
#    2747                 "function_call": function_call,
#    2748                 "functions": functions,
#    2749                 "logit_bias": logit_bias,
#    2750                 "logprobs": logprobs,
#    2751                 "max_completion_tokens": max_completion_tokens,
#    2752                 "max_tokens": max_tokens,
#    2753                 "metadata": metadata,
#    2754                 "modalities": modalities,
#    2755                 "n": n,
#    2756                 "parallel_tool_calls": parallel_tool_calls,
#    2757                 "prediction": prediction,
#    2758                 "presence_penalty": presence_penalty,
#    2759                 "prompt_cache_key": prompt_cache_key,
#    2760                 "prompt_cache_retention": prompt_cache_retention,
#    2761                 "reasoning_effort": reasoning_effort,
#    2762                 "response_format": response_format,
#    2763                 "safety_identifier": safety_identifier,
#    2764                 "seed": seed,
#    2765                 "service_tier": service_tier,
#    2766                 "stop": stop,
#    2767                 "store": store,
#    2768                 "stream": stream,
#    2769                 "stream_options": stream_options,
#    2770                 "temperature": temperature,
#    2771                 "tool_choice": tool_choice,
#    2772                 "tools": tools,
#    2773                 "top_logprobs": top_logprobs,
#    2774                 "top_p": top_p,
#    2775                 "user": user,
#    2776                 "verbosity": verbosity,
#    2777                 "web_search_options": web_search_options,
#    2778             },
#    2779             completion_create_params.CompletionCreateParamsStreaming
#    2780             if stream
#    2781             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2782         ),
#    2783         options=make_request_options(
#    2784             extra_headers=extra_headers,
#    2785             extra_query=extra_query,
#    2786             extra_body=extra_body,
#    2787             timeout=timeout,
#    2788             security={"bearer_auth": True},
#    2789         ),
#    2790         cast_to=ChatCompletion,
#    2791         stream=stream or False,
#    2792         stream_cls=AsyncStream[ChatCompletionChunk],
#    2793     )
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_base_client.py:1931, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1922     warnings.warn(
#    1923         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1924         "Please pass raw bytes via the `content` parameter instead.",
#    1925         DeprecationWarning,
#    1926         stacklevel=2,
#    1927     )
#    1928 opts = FinalRequestOptions.construct(
#    1929     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1930 )
# -> 1931 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/miniforge3/envs/granite-switch/lib/python3.13/site-packages/openai/_base_client.py:1683, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1680         continue
#    1682     log.debug("Raising connection error")
# -> 1683     raise APIConnectionError(request=request) from err
#    1685 log.debug(
#    1686     'HTTP Response: %s %s "%i %s" %s',
#    1687     request.method,
#    (...)   1691     response.headers,
#    1692 )
#    1693 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
# Q2 — unanswerable: cooking is out of scope for a government-services corpus,
# even though retrieval will still return its top-K most-similar passages.
_ = answerable("What's the best recipe for sourdough bread?")

# %% [markdown]
# ## 6 · Next steps
#
# - **Add the rest of the pipeline.** [`rag_full_pipeline.ipynb`](./rag_full_pipeline.ipynb) layers query rewrite, clarification, grounded generation, citations, and guardian harm + scope checks on top of the same corpus and answerability check.
# - **Compose your own checkpoint.** [`compose_granite_switch.ipynb`](./compose_granite_switch.ipynb) walks through building a Granite Switch model from the IBM adapter libraries.
# - **Watch ALORA vs LoRA race.** [`alora_vs_lora_race.ipynb`](./alora_vs_lora_race.ipynb) compares the two activation styles head-to-head on the same workload.
